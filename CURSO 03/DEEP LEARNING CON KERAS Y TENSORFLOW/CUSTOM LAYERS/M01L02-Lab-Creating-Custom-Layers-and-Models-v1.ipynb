# %% [markdown]
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/BQm_EV6i0_j80CQZ8vcLvw/SN-web-lightmode.png)

# %% [markdown]
# # **Laboratorio: Creación de capas y modelos personalizados**
#
# ###### Tiempo estimado necesario: 30 minutos
#
# En este laboratorio, aprenderá a crear capas personalizadas e integrarlas en un modelo de Keras. Compilará, entrenará y evaluará el modelo.
#
# ##### Objetivos de aprendizaje
#
# Al finalizar este laboratorio, podrá:
# - Crear capas personalizadas e integrarlas en un modelo de Keras
# - Compilar, entrenar y evaluar el modelo
#
# ##### Requisitos previos:
# - Conocimientos básicos de Python y Keras.

# %% [markdown]
# #### Steps
#
# **Step 1: Import libraries**
#
# Before you start, import the required libraries: TensorFlow and Keras. Keras is included within TensorFlow as `tensorflow.keras`.

# %%
# !pip install tensorflow==2.16.2
import tensorflow as tf
from tensorflow.keras.layers import Layer
from tensorflow.keras.models import Sequential

# %% [markdown]
# **Paso 2: Defina una capa personalizada**
#
# Defina una capa densa personalizada con 32 unidades y activación de ReLU.

# %%
class CustomDenseLayer(Layer):
    def __init__(self, units=32):
        super(CustomDenseLayer, self).__init__()
        self.units = units

    def build(self, input_shape):
        self.w = self.add_weight(shape=(input_shape[-1], self.units),
                                 initializer='random_normal',
                                 trainable=True)
        self.b = self.add_weight(shape=(self.units,),
                                 initializer='zeros',
                                 trainable=True)
    def call(self, inputs):
        return tf.nn.relu(tf.matmul(inputs, self.w) + self.b)

# %% [markdown]
# **Paso 3: Integrar la capa personalizada en un modelo**
#
# Crear un modelo Keras utilizando la capa personalizada.

# %%
from tensorflow.keras.layers import Softmax

# Define the model with Softmax in the output layer
model = Sequential([
    CustomDenseLayer(128),
    CustomDenseLayer(10),  # Hidden layer with ReLU activation
    Softmax()              # Output layer with Softmax activation for multi-class classification
])

# %% [markdown]
# La función de activación **Softmax** se utiliza en la capa de salida para tareas de clasificación de múltiples clases, lo que garantiza que el modelo genere probabilidades que sumen 1 para cada clase, lo que se alinea con la entropía cruzada categórica como función de pérdida. Este ajuste garantiza que el modelo esté optimizado correctamente para la clasificación de múltiples clases.

# %% [markdown]
# **Paso 4: compilar el modelo**
#
# Compile el modelo con el optimizador Adam y la pérdida de entropía cruzada categórica.

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy')
print("Model summary before building:")
model.summary()

# Build the model to show parameters
model.build((1000, 20))
print("\nModel summary after building:")
model.summary()

# %% [markdown]
# **Step 5: Train the model**
#
# Train the model on some example data. For this example, you will generate random data for training. In practice, use a real data set.

# %%
import numpy as np 

# Generate random data 
x_train = np.random.random((1000, 20)) 
y_train = np.random.randint(10, size=(1000, 1)) 

# Convert labels to categorical one-hot encoding 
y_train = tf.keras.utils.to_categorical(y_train, num_classes=10) 
model.fit(x_train, y_train, epochs=10, batch_size=32)

# %% [markdown]
# **Paso 6: evaluar el modelo**
#
# Evalúa el modelo usando datos de prueba para ver su rendimiento.
#
# Para este ejemplo, generarás datos de prueba aleatorios. En la práctica, usarás un conjunto de datos reales.

# %%
# Generate random test data 
x_test = np.random.random((200, 20)) 
y_test = np.random.randint(10, size=(200, 1)) 

# Convert labels to categorical one-hot encoding 
y_test = tf.keras.utils.to_categorical(y_test, num_classes=10) 

# Evaluate the model 
loss = model.evaluate(x_test, y_test) 
print(f'Test loss: {loss}')

# %% [markdown]
# ### Exercises

# %% [markdown]
# #### Ejercicio 1: Visualizar la arquitectura del modelo
#
# **Objetivo:** Visualizar la arquitectura del modelo Keras personalizado para comprender su estructura.
#
# **Instrucciones:**
# 1. Utilice la función `plot_model` de `tensorflow.keras.utils` para visualizar la arquitectura del modelo.
# 2. Guarde el gráfico como un archivo de imagen.

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
#
# !pip install pydot graphviz
#
# from tensorflow.keras.utils import plot_model
#
# # Visualize the model architecture
# plot_model(model, to_file='model_architecture.png', show_shapes=True, show_layer_names=True)
#
#
#  ```
#
# </details>

# %% [markdown]
# #### Ejercicio 2: Agregar capa de abandono
# #### Exercise 2: Add Dropout Layer
#
# **Objetivo:** Mejorar el modelo agregando una capa de abandono para evitar el sobreajuste.
#
# **Instrucciones:**
# 1. Agregar una capa de abandono entre las capas densas personalizadas.
# 2. Recompilar el modelo y observar el impacto en el entrenamiento.

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
#
# from tensorflow.keras.layers import Dropout
#
# # Modify the model to include a Dropout layer
# model = Sequential([
#     CustomDenseLayer(64),
#     Dropout(0.5),
#     CustomDenseLayer(10)
# ])
#
# # Recompile the model
# model.compile(optimizer='adam', loss='categorical_crossentropy')
#
# # Train the model again
# model.fit(x_train, y_train, epochs=10, batch_size=32)
#  ```
#
# </details>

# %% [markdown]
# #### Ejercicio 3: Ajuste la cantidad de unidades en la capa personalizada
#
# **Objetivo:** Experimente con diferentes cantidades de unidades en la capa densa personalizada para observar el impacto en el rendimiento.
#
# **Instrucciones:**
# 1. Cambie la cantidad de unidades en `CustomDenseLayer` a 128.
# 2. Vuelva a compilar, entrenar y evaluar el modelo.

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
#
# # Define a custom layer with 128 units
# class CustomDenseLayer(Layer):
#     def __init__(self, units=128):
#         super(CustomDenseLayer, self).__init__()
#         self.units = units
#
#     def build(self, input_shape):
#         self.w = self.add_weight(shape=(input_shape[-1], self.units),
#                                  initializer='random_normal',
#                                  trainable=True)
#         self.b = self.add_weight(shape=(self.units,),
#                                  initializer='zeros',
#                                  trainable=True)
#
#     def call(self, inputs):
#         return tf.nn.relu(tf.matmul(inputs, self.w) + self.b)
#
# # Integrate the new custom layer into a model
# model = Sequential([
#     CustomDenseLayer(128),
#     CustomDenseLayer(10)
# ])
#
# # Recompile the model
# model.compile(optimizer='adam', loss='categorical_crossentropy')
#
# # Train the model again
# model.fit(x_train, y_train, epochs=10, batch_size=32)
#  ```
#
# </details>

# %% [markdown]
# ### Resumen
#
# Al completar estos ejercicios, los estudiantes podrán:
#
# 1. Visualizar la arquitectura de su modelo Keras personalizado.
# 2. Comprender el impacto de agregar capas Dropout para evitar el sobreajuste.
# 3. Experimentar con diferentes configuraciones de la capa densa personalizada para observar los cambios en el rendimiento.

# %% [markdown]
# ## Conclusion
#
# Congratulations! You have successfully created and trained a custom layer in Keras. This lab exercise demonstrated how to extend Keras’s capabilities by creating custom layers and integrating them into a model.

# %%
Copyright © IBM Corporation. All rights reserved.
