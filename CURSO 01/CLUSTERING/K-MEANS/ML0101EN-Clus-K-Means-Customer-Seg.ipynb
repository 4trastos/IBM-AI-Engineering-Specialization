# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>
#
#
# # K-Means Clustering
#
#
# Estimated time needed: **25** minutes
#
#
# ## Objectives
#
# After completing this lab you will be able to:
#
# * Use scikit-learn's K-Means Clustering to cluster data

# %% [markdown]
# ## Introducción
#
# Existen muchos modelos de **clustering**. En este cuaderno, presentaremos el modelo que se considera uno de los más simples entre ellos. A pesar de su simplicidad, **K-means** se usa ampliamente para el agrupamiento en muchas aplicaciones de ciencia de datos, y es especialmente útil si necesita descubrir rápidamente información a partir de **unlabeled data**. En este cuaderno, aprenderá a usar k-means para la segmentación de clientes.
#
# Algunas aplicaciones reales de k-means:
# - Segmentación de clientes
# - Comprender lo que los visitantes de un sitio web intentan lograr
# - Reconocimiento de patrones
# - Aprendizaje automático
# - Compresión de datos
#
# En este cuaderno, practicamos el agrupamiento de k-means con 2 ejemplos:
# - k-means en un conjunto de datos generado aleatoriamente
# - Uso de k-means para la segmentación de clientes

# %% [markdown]
# <h1>Table of contents</h1>
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#     <ul>
#         <li><a href="#random_generated_dataset">k-Means on a randomly generated dataset</a></li>
#             <ol>
#                 <li><a href="#setting_up_K_means">Setting up K-Means</a></li>
#                 <li><a href="#creating_visual_plot">Creating the Visual Plot</a></li>
#             </ol>
#         <p></p>
#         <li><a href="#customer_segmentation_K_means">Customer Segmentation with K-Means</a></li>
#             <ol>
#                 <li><a href="#pre_processing">Pre-processing</a></li>
#                 <li><a href="#modeling">Modeling</a></li>
#                 <li><a href="#insights">Insights</a></li>
#             </ol>
#     </ul>
# </div>
# <br>
# <hr>

# %% [markdown]
# ### Import libraries
# Primero, importemos las bibliotecas necesarias.
# Ejecute también <b> %matplotlib inline </b>, ya que en esta sección realizaremos gráficos.

# %%
# Surpress warnings:
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn

# %%
import random 
import numpy as np 
import matplotlib.pyplot as plt 
from sklearn.cluster import KMeans 
from sklearn.datasets import make_blobs 
# %matplotlib inline

# %% [markdown]
# <h1 id="random_generated_dataset">k-Means on a randomly generated dataset</h1>
#
# Creemos nuestro propio conjunto de datos para este laboratorio!

# %% [markdown]
# Primero debemos establecer una semilla aleatoria. Utilice la función <b>random.seed() de numpy</b>, donde la semilla se establecerá en <b>0</b>.

# %%
np.random.seed(0)

# %% [markdown]
# A continuación, crearemos <i>grupos aleatorios</i> de puntos utilizando la clase <b>make_blobs</b>. La clase <b>make_blobs</b> puede aceptar muchas entradas, pero utilizaremos estas específicas. <br><br>
# <b> <u> Input </u> </b>
# <ul>
# <li> <b>n_samples</b>: La cantidad total de puntos divididos equitativamente entre los grupos. </li>
# <ul> <li> El valor será: 5000 </li> </ul>
# <li> <b>centers</b>: La cantidad de centros a generar o las ubicaciones fijas de los centros. </li>
# <ul> <li> El valor será: [[4, 4], [-2, -1], [2, -3],[1,1]] </li> </ul>
# <li> <b>cluster_std</b>: La desviación estándar de los grupos. </li>
# <ul> <li> El valor será: 0,9 </li> </ul>
# </ul>
# <br>
# <b> <u> Output </u> </b>
# <ul>
# <li> <b>X</b>: Matriz de formas [n_muestras, n_características]. (Matriz de características)</li>
# <ul> <li> Las muestras generadas. </li> </ul>
# <li> <b>y</b>: Matriz de formas [n_muestras]. (Vector de respuesta)</li>
# <ul> <li> Las etiquetas enteras para la pertenencia al grupo de cada muestra. </li> </ul>
# </ul>

# %%
X, y = make_blobs(n_samples=5000, centers=[[4,4], [-2, -1], [2, -3], [1, 1]], cluster_std=0.9)

# %% [markdown]
# Muestra el diagrama de dispersión de los datos generados aleatoriamente.

# %%
plt.scatter(X[:, 0], X[:, 1], marker='.')

# %% [markdown]
# <h2 id="setting_up_K_means">Setting up K-Means</h2>
# Ahora que tenemos nuestros datos aleatorios, configuremos nuestro agrupamiento K-Means.

# %% [markdown]
# La clase KMeans tiene muchos parámetros que se pueden utilizar, pero utilizaremos estos tres:
# <ul>
# <li> <b>init</b>: método de inicialización de los centroides. </li>
# <ul>
# <li> El valor será: "k-means++" </li>
# <li> k-means++: selecciona los centros de clúster iniciales para la agrupación en clústeres k-mean de una manera inteligente para acelerar la convergencia.</li>
# </ul>
# <li> <b>n_clusters</b>: la cantidad de clústeres que se formarán, así como la cantidad de centroides que se generarán. </li>
# <ul> <li> El valor será: 4 (ya que tenemos 4 centros)</li> </ul>
# <li> <b>n_init</b>: cantidad de veces que se ejecutará el algoritmo k-means con diferentes semillas de centroides. Los resultados finales serán la mejor salida de n_init ejecuciones consecutivas en términos de inercia. </li>
# <ul> <li> El valor será: 12 </li> </ul>
# </ul>
#
# Inicialice KMeans con estos parámetros, donde el parámetro de salida se denomina <b>k_means</b>.

# %%
k_means = KMeans(init = "k-means++", n_clusters = 4, n_init = 12)

# %% [markdown]
# Ahora ajustemos el modelo KMeans con la matriz de características que creamos anteriormente, <b> X </b>.

# %%
k_means.fit(X)

# %% [markdown]
# Ahora tomemos las etiquetas para cada punto en el modelo usando el atributo <b> .labels\_ </b> de KMeans y guardémoslo como <b> k_means_labels </b>.

# %%
k_means_labels = k_means.labels_
k_means_labels

# %% [markdown]
# También obtendremos las coordenadas de los centros de los clústeres utilizando <b>.cluster&#95;centers&#95; </b> de KMeans y las guardaremos como <b>k_means_cluster_centers </b>.

# %%
k_means_cluster_centers = k_means.cluster_centers_
k_means_cluster_centers

# %% [markdown]
# <h2 id="creating_visual_plot">Creating the Visual Plot</h2>
#
# Ahora que tenemos los datos aleatorios generados y el modelo KMeans inicializado, ¡graficiémoslos y veamos cómo se ve!

# %% [markdown]
# Lea el código y los comentarios para comprender cómo trazar el modelo.

# %%
# Initialize the plot with the specified dimensions.
fig = plt.figure(figsize=(6, 4))

# Colors uses a color map, which will produce an array of colors based on
# the number of labels there are. We use set(k_means_labels) to get the
# unique labels.
colors = plt.cm.Spectral(np.linspace(0, 1, len(set(k_means_labels))))

# Create a plot
ax = fig.add_subplot(1, 1, 1)

# For loop that plots the data points and centroids.
# k will range from 0-3, which will match the possible clusters that each
# data point is in.
for k, col in zip(range(len([[4,4], [-2, -1], [2, -3], [1, 1]])), colors):

    # Create a list of all data points, where the data points that are 
    # in the cluster (ex. cluster 0) are labeled as true, else they are
    # labeled as false.
    my_members = (k_means_labels == k)
    
    # Define the centroid, or cluster center.
    cluster_center = k_means_cluster_centers[k]
    
    # Plots the datapoints with color col.
    ax.plot(X[my_members, 0], X[my_members, 1], 'w', markerfacecolor=col, marker='.')
    
    # Plots the centroids with specified color, but with a darker outline
    ax.plot(cluster_center[0], cluster_center[1], 'o', markerfacecolor=col,  markeredgecolor='k', markersize=6)

# Title of the plot
ax.set_title('KMeans')

# Remove x-axis ticks
ax.set_xticks(())

# Remove y-axis ticks
ax.set_yticks(())

# Show the plot
plt.show()

# %% [markdown]
# ## Practice
# Intente agrupar el conjunto de datos anterior en tres grupos.
# Aviso: no vuelva a generar los datos, utilice el mismo conjunto de datos que el anterior.

# %%
# write your code here

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# k_means3 = KMeans(init = "k-means++", n_clusters = 3, n_init = 12)
# k_means3.fit(X)
# fig = plt.figure(figsize=(6, 4))
# colors = plt.cm.Spectral(np.linspace(0, 1, len(set(k_means3.labels_))))
# ax = fig.add_subplot(1, 1, 1)
# for k, col in zip(range(len(k_means3.cluster_centers_)), colors):
#     my_members = (k_means3.labels_ == k)
#     cluster_center = k_means3.cluster_centers_[k]
#     ax.plot(X[my_members, 0], X[my_members, 1], 'w', markerfacecolor=col, marker='.')
#     ax.plot(cluster_center[0], cluster_center[1], 'o', markerfacecolor=col,  markeredgecolor='k', markersize=6)
# plt.show()
#
# ```
#
# </details>

# %% [markdown]
# <h1 id="customer_segmentation_K_means">Segmentación de clientes con K-Means</h1>
#
# Imagina que tienes un conjunto de datos de clientes y necesitas aplicar la segmentación de clientes a estos datos históricos.
# La segmentación de clientes es la práctica de dividir una base de clientes en grupos de individuos que tienen características similares. Es una estrategia importante, ya que una empresa puede dirigirse a estos grupos específicos de clientes y asignar recursos de marketing de manera eficaz. Por ejemplo, un grupo puede contener clientes que generan grandes beneficios y representan un riesgo bajo, es decir, que tienen más probabilidades de comprar productos o suscribirse a un servicio. Una tarea empresarial es retener a esos clientes. Otro grupo puede incluir clientes de organizaciones sin fines de lucro, etc.

# %% [markdown]
# ### Load Data From CSV File
# Before you can work with the data, let's use pandas to read the dataset from IBM Object Storage.

# %%
import pandas as pd
cust_df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ML0101EN-SkillsNetwork/labs/Module%204/data/Cust_Segmentation.csv")
cust_df.head()

# %% [markdown]
# <h2 id="pre_processing">Pre-processing</h2

# %% [markdown]
# Como puede ver, __Address__ en este conjunto de datos es una variable categórica. El algoritmo k-means no se aplica directamente a las variables categóricas porque la función de distancia euclidiana no es realmente significativa para las variables discretas. Por lo tanto, eliminemos esta función y ejecutemos la agrupación.

# %%
df = cust_df.drop('Address', axis=1)
df.head()

# %% [markdown]
# #### Normalización sobre la desviación estándar
# Ahora normalicemos el conjunto de datos. Pero, ¿por qué necesitamos la normalización en primer lugar? La normalización es un método estadístico que ayuda a los algoritmos matemáticos a interpretar características con diferentes magnitudes y distribuciones de manera uniforme. Usamos __StandardScaler()__ para normalizar nuestro conjunto de datos.

# %%
from sklearn.preprocessing import StandardScaler
X = df.values[:,1:]
X = np.nan_to_num(X)
Clus_dataSet = StandardScaler().fit_transform(X)
Clus_dataSet

# %% [markdown]
# <h2 id="modeling">Modeling</h2>

# %% [markdown]
# En nuestro ejemplo (si no tuviéramos acceso al algoritmo k-means), sería lo mismo que suponer que cada grupo de clientes tendría cierta edad, ingresos, educación, etc., con múltiples pruebas y experimentos. Sin embargo, utilizando el agrupamiento de K-means podemos hacer todo este proceso mucho más fácilmente.
#
# Apliquemos k-means a nuestro conjunto de datos y observemos las etiquetas de los clústeres.

# %%
clusterNum = 3
k_means = KMeans(init = "k-means++", n_clusters = clusterNum, n_init = 12)
k_means.fit(X)
labels = k_means.labels_
print(labels)

# %% [markdown]
# <h2 id="insights">Insights</h2>
#
# Asignamos las etiquetas a cada fila en el marco de datos.

# %%
df["Clus_km"] = labels
df.head(5)

# %% [markdown]
# Podemos comprobar fácilmente los valores del centroide promediando las características en cada grupo.

# %%
df.groupby('Clus_km').mean()

# %% [markdown]
# Ahora, veamos la distribución de los clientes según su edad e ingresos:

# %%
area = np.pi * ( X[:, 1])**2  
plt.scatter(X[:, 0], X[:, 3], s=area, c=labels.astype(float), alpha=0.5)
plt.xlabel('Age', fontsize=18)
plt.ylabel('Income', fontsize=16)

plt.show()

# %%
# Gráfico 3D

from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(1, figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

plt.cla()
# plt.ylabel('Age', fontsize=18)
# plt.xlabel('Income', fontsize=16)
# plt.zlabel('Education', fontsize=16)
ax.set_xlabel('Education', fontsize=12)
ax.set_ylabel('Age', fontsize=12)
ax.set_zlabel('Income', fontsize=12)

ax.scatter(X[:, 1], X[:, 0], X[:, 3], c= labels.astype(float))
plt.show()

# %% [markdown]
# k-means dividirá a sus clientes en grupos mutuamente excluyentes, por ejemplo, en 3 grupos. Los clientes de cada grupo son similares entre sí desde el punto de vista demográfico.
# Ahora podemos crear un perfil para cada grupo, teniendo en cuenta las características comunes de cada grupo.
# Por ejemplo, los 3 grupos pueden ser:
#
# - AFORTUNADOS, EDUCADOS Y DE EDAD MAYOR
# - DE MEDIANA EDAD E INGRESOS MEDIOS
# - JÓVENES Y DE BAJOS INGRESOS

# %% [markdown]
# ### Thank you for completing this lab!
#
#
# ## Author
#
# Saeed Aghabozorgi
#
#
# ### Other Contributors
#
# <a href="https://www.linkedin.com/in/joseph-s-50398b136/" target="_blank">Joseph Santarcangelo</a>
#
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>
#
# <!--
# ## Change Log
#
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2020-11-03  | 2.1  | Lakshmi  |  Updated URL of csv |
# | 2020-08-27  | 2.0  | Lavanya  |  Moved lab to course repo in GitLab |
# |   |   |   |   |
# |   |   |   |   |
# --!>
